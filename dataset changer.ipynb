# %%
import pandas as pd;

# %%
df=pd.read_csv(r"C:\Users\Kick Buttowski\Documents\College work\Co-Curricular\Projects\Datasets\Politics dataset\LokSabha2019.csv")

# %%
df
# Out:
#                   Candidate                               Party  \
# 0        Kuldeep Rai Sharma                                 INC
# 1               Ayan Mandal                                AITC
# 2            C G Saji Kumar  All India Hindustan Congress Party
# 3               C U Rasheed                                 IND
# 4     Gour Chandra Majumder                                 IND
# ...                     ...                                 ...
# 7963         Maksuda Khatun                              CPI(M)
# 7964          Minati Sarkar                             SUCI(C)
# 7965   Shoma Ranisree Roy\t                                 INC
# 7966            Simal Saren                 Indian Unity Centre
# 7967    Susanta Kumar Dalui                                 IND
#
#       Criminal Cases              Education  Age  Total Assets  \
# 0                  0  Graduate Professional   52   132233012.0
# 1                  0               Graduate   30     7270440.0
# ...

# %%
w=pd.read_csv(r"C:\Users\Kick Buttowski\Desktop\19.csv",header=None)
winners=[]
for i in w[0]:
    winners.append(i.upper())
len(winners)
# Out:
# 522

# %%
import numpy as np
a=np.setdiff1d(winners,df['Candidate']).tolist()
len(a)
# Out:
# 521

# %%
col=[]
count = 0
for i in df['Candidate']:
    if i.upper() in winners:
        col.append('1')
        winners.remove(i.upper())  
    else:
        col.append('0')

# %%
df['Winner']=col

# %%
df.groupby(['Winner']).apply(lambda x : x.count())
# Out:
#         Candidate  Party  Criminal Cases  Education   Age  Total Assets  \
# Winner
# 0            7967   7967            7967       7967  7967          7907
# 1               1      1               1          1     1             1
#
#         Constituency  Liabilities  Winner  Gender
# Winner
# 0               7967         7967    7967    7967
# 1                  1            1       1       1

# %%
df.to_csv("2019.csv")

# %%
len(winners)
# Out:
# 452
